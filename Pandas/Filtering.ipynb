# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# ...

# %%
print(df["Actor"])
# Out:
# 0         Shah Rukh Khan
# 1            Salman Khan
# 2             Aamir Khan
# 3          Ranbir Kapoor
# 4          Ranveer Singh
# 5     Ayushmann Khurrana
# 6          Rajkummar Rao
# 7         Hrithik Roshan
# 8           Akshay Kumar
# 9          Kartik Aaryan
# 10          Varun Dhawan
# 11         Vicky Kaushal
# Name: Actor, dtype: object

# %%
df[["Film","Year","IMDb"]]
# Out:
#                         Film  Year  IMDb
# 0                    Pathaan  2023   7.2
# 1            Tiger Zinda Hai  2017   6.0
# 2                     Dangal  2016   8.4
# 3                 Brahmastra  2022   5.6
# 4                  Padmaavat  2018   7.0
# 5                  Andhadhun  2018   8.3
# 6                      Stree  2018   7.5
# 7                        War  2019   6.5
# 8                 Good Newwz  2019   7.0
# 9          Bhool Bhulaiyaa 2  2022   5.9
# 10     Badrinath Ki Dulhania  2017   6.1
# 11  Uri: The Surgical Strike  2019   8.2

# %%
df.loc[[0]]
# Out:
#             Actor     Film  Year   Genre  BoxOffice(INR Crore)  IMDb
# 0  Shah Rukh Khan  Pathaan  2023  Action                  1050   7.2

# %%
df.iloc[[1,3]]
# Out:
#            Actor             Film  Year    Genre  BoxOffice(INR Crore)  IMDb
# 1    Salman Khan  Tiger Zinda Hai  2017   Action                   565   6.0
# 3  Ranbir Kapoor       Brahmastra  2022  Fantasy                   431   5.6

# %%
df.loc[9,"Actor"]
# Out:
# 'Kartik Aaryan'

# %%
df.iloc[9,1]
# Out:
# 'Bhool Bhulaiyaa 2'

# %%
df.loc[0:5:1,["Actor","Film"]]
# Out:
#                 Actor             Film
# 0      Shah Rukh Khan          Pathaan
# 1         Salman Khan  Tiger Zinda Hai
# 2          Aamir Khan           Dangal
# 3       Ranbir Kapoor       Brahmastra
# 4       Ranveer Singh        Padmaavat
# 5  Ayushmann Khurrana        Andhadhun

# %%
df.iloc[0:5:1,0:2]
# Out:
#             Actor             Film
# 0  Shah Rukh Khan          Pathaan
# 1     Salman Khan  Tiger Zinda Hai
# 2      Aamir Khan           Dangal
# 3   Ranbir Kapoor       Brahmastra
# 4   Ranveer Singh        Padmaavat

# %%
df.at[9,"Film"]
# Out:
# 'Bhool Bhulaiyaa 2'

# %%
df.iat[9,1]
# Out:
# 'Bhool Bhulaiyaa 2'

# %%
df[df["IMDb"]>6]
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 2                   2024   8.4
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# ...

# %%
df[df["IMDb"]>6]["Actor"]
# Out:
# 0         Shah Rukh Khan
# 2             Aamir Khan
# 4          Ranveer Singh
# 5     Ayushmann Khurrana
# 6          Rajkummar Rao
# 7         Hrithik Roshan
# 8           Akshay Kumar
# 10          Varun Dhawan
# 11         Vicky Kaushal
# Name: Actor, dtype: object

# %%
df[(df["IMDb"]>6) & (df["Year"] > 2018 )]
# Out:
#              Actor                      Film  Year   Genre  \
# 0   Shah Rukh Khan                   Pathaan  2023  Action
# 7   Hrithik Roshan                       War  2019  Action
# 8     Akshay Kumar                Good Newwz  2019  Comedy
# 11   Vicky Kaushal  Uri: The Surgical Strike  2019  Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 7                    475   6.5
# 8                    318   7.0
# 11                   342   8.2

# %%
df[(df["IMDb"]>6) | (df["Year"] < 2018 )]
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 1                    565   6.0
# 2                   2024   8.4
# 4                    585   7.0
# ...

# %%
df.query(" `BoxOffice(INR Crore)` >= 585 ")
# Out:
#             Actor       Film  Year       Genre  BoxOffice(INR Crore)  IMDb
# 0  Shah Rukh Khan    Pathaan  2023      Action                  1050   7.2
# 2      Aamir Khan     Dangal  2016   Biography                  2024   8.4
# 4   Ranveer Singh  Padmaavat  2018  Historical                   585   7.0
